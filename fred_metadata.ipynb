# %%
import numpy as np
import pandas as pd

import pickle

# %%
df = pd.read_csv('/home/ubuntu/csvs/codes_to_use.csv')

# %%
df
# Out:
#        Unnamed: 0        code  \
# 0            1072     A038RC1
# 1            1080     A041RC1
# 2            1085     A045RC1
# 3            1088     A048RC1
# 4            1117     A061RC1
# 5            1123     A063RC1
# 6            1320     A132RC1
# 7            1701     A229RC0
# 8            1870      A31SNO
# 9            1871      A31STI
# 10           1872      A31SUO
# 11           1874      A31SVS
# 12           1927      A32SNO
# 13           1928      A32STI
# 14           1929      A32SUO
# 15           1931      A32SVS
# 16           2010      A33SNO
# 17           2011      A33STI
# 18           2012      A33SUO
# 19           2014      A33SVS
# 20           2097      A34SNO
# 21           2098      A34STI
# 22           2099      A34SUO
# 23           2101      A34SVS
# 24           2103      A34XNO
# 25           2104      A34XTI
# 26           2105      A34XUO
# 27           2106      A34XVS
# 28           2178      A35SNO
# 29           2179      A35STI
# ...

# %%
codes = df['code'].tolist()

# %%
len(codes)
# Out:
# 28779

# %%
with open('/home/ubuntu/notebooks/codes.pickle', 'wb') as p:
    pickle.dump(codes, p)
