# %%
import numpy as np
import pandas as pd

import fix_yahoo_finance as yf
from pandas_datareader import data as pdr

# %load_ext zipline

# %%
yf.pdr_override()

# %%
# %%zipline --start 2016-1-1 --end 2018-1-1
# from zipline.api import order_target, record, symbol
#
# def initialize(context):
#     context.i = 0
#     context.asset = symbol('VTI')
#
# def handle_data(context, data):
#     context.i += 1
#     if context.i < 300:
#         return
#
#     short_mavg = data.history(context.asset, 'price', bar_count=100, frequency='1d').mean()
#     long_mavg = data.history(context.asset, 'price', bar_count=300, frequency='1d').mean()
#
#     if short_mavg > long_mavg:
#         order_target(context.asset, 100)
#     elif short_mavg < long_mavg:
#         order_target(context.asset, 0)
#
#     record(IVV=data.current(context.asset, 'price'),
#            short_mavg=short_mavg,
#            long_mavg=long_mavg)
# Out:
# ---------------------------------------------------------------------------
# SymbolNotFound                            Traceback (most recent call last)
# <ipython-input-10-f4ee9841d32d> in <module>()
# ...

# %%
_.head()
# Out:
#                            IVV  algo_volatility  algorithm_period_return  \
# 2016-01-04 21:00:00+00:00  NaN              NaN                      0.0
# 2016-01-05 21:00:00+00:00  NaN              0.0                      0.0
# 2016-01-06 21:00:00+00:00  NaN              0.0                      0.0
# 2016-01-07 21:00:00+00:00  NaN              0.0                      0.0
# 2016-01-08 21:00:00+00:00  NaN              0.0                      0.0
#
#                            alpha  benchmark_period_return  \
# 2016-01-04 21:00:00+00:00    NaN                -0.013983
# 2016-01-05 21:00:00+00:00    0.0                -0.012311
# 2016-01-06 21:00:00+00:00    0.0                -0.024771
# 2016-01-07 21:00:00+00:00    0.0                -0.048168
# 2016-01-08 21:00:00+00:00    0.0                -0.058601
#
#                            benchmark_volatility  beta  capital_used  \
# 2016-01-04 21:00:00+00:00                   NaN   NaN           0.0
# ...

# %%
start = datetime.datetime(2016, 1, 1)
end = datetime.datetime(2019, 1, 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-50b6f6d54575> in <module>()
# ----> 1 start = datetime.datetime(2016, 1, 1)
#       2 end = datetime.datetime(2019, 1, 1)
#
# NameError: name 'datetime' is not defined

# %%
pdr.get_data_yahoo(['SPY', 'BNDX'], actions=True)
# Out:
# [*********************100%***********************]  2 of 2 downloaded
#                  Open                   High                    Low  \
#                  BNDX         SPY       BNDX         SPY       BNDX
# Date
# 1993-01-29        NaN   43.968700        NaN   43.968700        NaN
# 1993-02-01        NaN   43.968700        NaN   44.250000        NaN
# 1993-02-02        NaN   44.218700        NaN   44.375000        NaN
# 1993-02-03        NaN   44.406200        NaN   44.843700        NaN
# 1993-02-04        NaN   44.968700        NaN   45.093700        NaN
# 1993-02-05        NaN   44.968700        NaN   45.062500        NaN
# 1993-02-08        NaN   44.968700        NaN   45.125000        NaN
# 1993-02-09        NaN   44.812500        NaN   44.812500        NaN
# 1993-02-10        NaN   44.656200        NaN   44.750000        NaN
# 1993-02-11        NaN   44.781200        NaN   45.125000        NaN
# 1993-02-12        NaN   44.875000        NaN   44.875000        NaN
# ...

# %%
pdr.get_data_yahoo_actions('SPY', start, end)
# Out:
#               action    value
# 2018-12-21  DIVIDEND  1.43500
# 2018-09-21  DIVIDEND  1.32300
# 2018-06-15  DIVIDEND  1.24600
# 2018-03-16  DIVIDEND  1.09700
# 2017-12-15  DIVIDEND  1.35100
# 2017-09-15  DIVIDEND  1.23500
# 2017-06-16  DIVIDEND  1.18300
# 2017-03-17  DIVIDEND  1.03300
# 2016-12-16  DIVIDEND  1.32893
# 2016-09-16  DIVIDEND  1.08207
# 2016-06-17  DIVIDEND  1.07844
# 2016-03-18  DIVIDEND  1.04960

# %%
import pandas_datareader as pdr

# %%
# Out:
# pandas_datareader.mstar.daily.MorningstarDailyReader

# %%
pdr.YahooActionReader
# Out:
# {u'asks': [{u'price': 277.41, u'size': 100, u'timestamp': 1551904404470},
#   {u'price': 277.42, u'size': 100, u'timestamp': 1551904390505},
#   {u'price': 277.43, u'size': 600, u'timestamp': 1551904390506},
#   {u'price': 277.44, u'size': 100, u'timestamp': 1551904398238},
#   {u'price': 277.45, u'size': 1000, u'timestamp': 1551904389888},
#   {u'price': 277.46, u'size': 500, u'timestamp': 1551904382645},
#   {u'price': 277.47, u'size': 100, u'timestamp': 1551904397856},
#   {u'price': 277.48, u'size': 600, u'timestamp': 1551904276332},
#   {u'price': 277.49, u'size': 100, u'timestamp': 1551904343349},
#   {u'price': 277.5, u'size': 600, u'timestamp': 1551904373443},
#   {u'price': 277.51, u'size': 100, u'timestamp': 1551904347922},
#   {u'price': 277.52, u'size': 100, u'timestamp': 1551904371003},
#   {u'price': 277.53, u'size': 600, u'timestamp': 1551904380913},
#   {u'price': 277.54, u'size': 100, u'timestamp': 1551904375085},
# ...

# %%
nasdaq = pdr.get_nasdaq_symbols()

# %%
nasdaq[nasdaq['ETF'] == True]
# Out:
#         Nasdaq Traded                                      Security Name  \
# Symbol
# AAAU             True                       Perth Mint Physical Gold ETF
# AADR             True                AdvisorShares Dorsey Wright ADR ETF
# AAXJ             True  iShares MSCI All Country Asia ex Japan Index Fund
# ACES             True                              ALPS Clean Energy ETF
# ACIM             True                             SPDR MSCI ACWI IMI ETF
# ACSG             True  Xtrackers MSCI ACWI ex USA ESG Leaders Equity ETF
# ACSI             True                 American Customer Satisfaction ETF
# ACT              True                             AdvisorShares Vice ETF
# ACWF             True           iShares Edge MSCI Multifactor Global ETF
# ACWI             True                       iShares MSCI ACWI Index Fund
# ACWV             True               iShares Edge MSCI Min Vol Global ETF
# ACWX             True                 iShares MSCI ACWI ex US Index Fund
# ...

# %%
nasdaq.loc['AAAU']
# Out:
# Nasdaq Traded                               True
# Security Name       Perth Mint Physical Gold ETF
# Listing Exchange                               P
# Market Category
# ETF                                         True
# Round Lot Size                               100
# Test Issue                                 False
# Financial Status                             NaN
# CQS Symbol                                  AAAU
# NASDAQ Symbol                               AAAU
# NextShares                                 False
# Name: AAAU, dtype: object

# %%
etfs = pd.read_csv('/Users/Stephen/Downloads/ETFList.csv')

# %%
etfs[etfs['Symbol'] == 'AAAU']
# Out:
#     Symbol                          Name  LastSale  NetChange  \
# 367   AAAU  Perth Mint Physical Gold ETF   12.8499    -0.0087
#
#     NetChangeDirection  PercentChange  1YrPercentChange
# 367               down           0.07              9.53

# %%
len(nasdaq[nasdaq['ETF'] == True])
# Out:
# 2093

# %%
len(etfs)
# Out:
# 2214

# %%
etfs1 = pd.read_csv('/Users/Stephen/Downloads/ETFList (1).csv')

# %%
len(etfs1)
# Out:
# 2214

# %%
pdr.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-07b953367a9c> in <module>()
# ----> 1 pdr.get_data_yahoo()
#
# TypeError: download() takes at least 1 argument (0 given)
