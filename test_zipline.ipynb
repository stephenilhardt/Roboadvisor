# %%
import numpy as np
import pandas as pd

from zipline.data.bundles import register
from zipline.data.bundles.csvdir import csvdir_equities

from zipline.api import symbol, order, record
import zipline

from fbprophet import Prophet

# %%
etfs = pd.read_csv('etfs_pivot.csv')

# %%
etf_tickers = etfs.columns.tolist()

# %%
etf_tickers.pop(0)
# Out:
# 'date'

# %%
etfs['date'] = pd.to_datetime(etfs['date'], format='%Y-%m-%d')

# %%
etfs_tickers = etfs[etfs['date'] < '2018'

# %%
etfs = etfs.set_index('date')

# %%
etf_spy = pd.DataFrame(etfs['SPY'])

# %%
etf_spy = etf_spy.reset_index()
etf_spy.columns = ['ds', 'y']

# %%
model = Prophet()
model.fit(etf_spy)

predict = model.predict(df)
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /home/ubuntu/anaconda3/envs/env_zipline/lib/python3.5/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# 0       169.201337
# 1       169.032235
# 2       169.028623
# 3       168.775960
# 4       168.597976
# 5       168.324542
# 6       168.094035
# 7       167.915859
# 8       167.786041
# 9       167.836322
# 10      167.650717
# 11      167.551465
# 12      167.366926
# 13      167.233962
# 14      167.160493
# 15      167.141092
# 16      167.306101
# 17      167.238190
# 18      167.258321
# 19      167.193636
# 20      167.179850
# 21      167.223793
# 22      167.319014
# 23      167.594881
# 24      167.633152
# 25      167.753922
# ...

# %%
etf_test = pd.DataFrame(index=etfs.index)
etf_test['SPY'] = predict['yhat'].tolist()

# %%
etf_test
# Out:
#                    SPY
# date
# 2014-03-17  169.201337
# 2014-03-18  169.032235
# 2014-03-19  169.028623
# 2014-03-20  168.775960
# 2014-03-21  168.597976
# 2014-03-22  168.324542
# 2014-03-23  168.094035
# 2014-03-24  167.915859
# 2014-03-25  167.786041
# 2014-03-26  167.836322
# 2014-03-27  167.650717
# 2014-03-28  167.551465
# 2014-03-29  167.366926
# 2014-03-30  167.233962
# 2014-03-31  167.160493
# 2014-04-01  167.141092
# 2014-04-02  167.306101
# 2014-04-03  167.238190
# 2014-04-04  167.258321
# 2014-04-05  167.193636
# 2014-04-06  167.179850
# 2014-04-07  167.223793
# 2014-04-08  167.319014
# 2014-04-09  167.594881
# 2014-04-10  167.633152
# 2014-04-11  167.753922
# 2014-04-12  167.783520
# 2014-04-13  167.856901
# 2014-04-14  167.980191
# 2014-04-15  168.146292
# ...                ...
# 2019-02-14  267.168287
# 2019-02-15  267.552968
# 2019-02-16  267.852820
# 2019-02-17  268.200253
# 2019-02-18  268.598652
# 2019-02-19  269.038051
# 2019-02-20  269.644316
# ...

# %%
predictions = pd.DataFrame(index=etfs.index)

for ticker in etf_tickers:
    df = pd.DataFrame(etfs[ticker])
    df = df.reset_index()
    df.columns = ['ds', 'y']
    
    model = Prophet(growth='linear')
    model.fit(df)
    
    etf_predictions = model.predict(df)
    predictions[ticker] = etf_predictions['yhat'].tolist()
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /home/ubuntu/anaconda3/envs/env_zipline/lib/python3.5/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# ...

# %%
len(predictions.columns)
# Out:
# 918

# %%
# %load_ext zipline

# %%
# %%zipline --start 2018-3-15 --end 2019-3-15 --bundle custom-csvdir-bundle
#
# from zipline.api import order, record, symbol
#
# def initialize(context):
#     pass
#
# def handle_data(context, data):
#     order(symbol('SPY'), 10)
#     record(SPY=data[symbol('SPY')].price)
# Out:
# UsageError: Cell magic `%%zipline` not found.
