# %%
import numpy as np
import pandas as pd

from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://ubuntu:project-kojak@18.188.49.181:5432/roboadvisor')

# %%
query = '''SELECT prices.*, dividends.dividend FROM prices 
LEFT JOIN dividends ON prices.ticker = dividends.ticker AND prices.date = dividends.date;'''

prices = pd.read_sql(query, engine, index_col = 'ticker')

# %%
prices['date_split'] = [str(date).split() for date in prices['date']]
prices['date'] = [date[0] for date in prices['date_split']]
prices['date'] = pd.to_datetime(prices['date'])

prices = prices.drop(['adjusted_close','date_split'], axis=1)

prices = prices.fillna(0.0)
prices['split'] = 1.0

# %%
tickers = prices.index

tickers = sorted(list(tickers))

tickers_set = set(tickers)
tickers_list = list(tickers_set)
tickers = [str(ticker) for ticker in tickers_list]

tickers = sorted(tickers)

# %%
prices = prices.drop_duplicates()

prices = prices.reset_index()
prices = prices[['ticker','date','open','high','low','close','volume','dividend','split']]

prices = prices.set_index('ticker')

prices = prices.sort_values(['ticker','date'])

# %%
prices
# Out:
#              date       open       high        low      close   volume  \
# ticker
# AAAU   2018-08-15  11.840000  11.840000  11.740000  11.740000    27300
# AAAU   2018-08-16  11.780000  11.800000  11.740000  11.740000   428400
# AAAU   2018-08-17  11.800000  11.820000  11.770000  11.820000    52400
# AAAU   2018-08-20  11.880000  11.910000  11.850000  11.900000    28700
# AAAU   2018-08-21  11.920000  11.950000  11.890000  11.930000    30600
# AAAU   2018-08-22  11.980000  11.980000  11.940000  11.960000   101200
# AAAU   2018-08-23  11.910000  11.920000  11.850000  11.850000    54800
# AAAU   2018-08-24  11.970000  12.080000  11.960000  12.050000   106500
# AAAU   2018-08-27  12.060000  12.130000  12.060000  12.100000   295100
# AAAU   2018-08-28  12.130000  12.130000  12.010000  12.010000    30400
# AAAU   2018-08-29  12.060000  12.060000  12.030000  12.050000    31800
# AAAU   2018-08-30  12.030000  12.030000  11.970000  12.010000   804500
# ...

# %%
len(prices)
# Out:
# 2878317

# %%
ticker_dfs = []

for ticker in tickers:
    ticker_frame = prices[prices.index == ticker]
    ticker_frame.to_csv('/home/ubuntu/csvs/{}.csv'.format(ticker), index=False)

# %%
prices
# Out:
#              date       open       high        low      close   volume  \
# ticker
# AAAU   2018-08-15  11.840000  11.840000  11.740000  11.740000    27300
# AAAU   2018-08-16  11.780000  11.800000  11.740000  11.740000   428400
# AAAU   2018-08-17  11.800000  11.820000  11.770000  11.820000    52400
# AAAU   2018-08-20  11.880000  11.910000  11.850000  11.900000    28700
# AAAU   2018-08-21  11.920000  11.950000  11.890000  11.930000    30600
# AAAU   2018-08-22  11.980000  11.980000  11.940000  11.960000   101200
# AAAU   2018-08-23  11.910000  11.920000  11.850000  11.850000    54800
# AAAU   2018-08-24  11.970000  12.080000  11.960000  12.050000   106500
# AAAU   2018-08-27  12.060000  12.130000  12.060000  12.100000   295100
# AAAU   2018-08-28  12.130000  12.130000  12.010000  12.010000    30400
# AAAU   2018-08-29  12.060000  12.060000  12.030000  12.050000    31800
# AAAU   2018-08-30  12.030000  12.030000  11.970000  12.010000   804500
# ...

# %%
dates = prices.date.unique()

# %%
dates = sorted(dates)

# %%
dates[0]
# Out:
# numpy.datetime64('2010-01-04T00:00:00.000000000')
