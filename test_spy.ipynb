# %%
import numpy as np
import pandas as pd
import pickle

import arima_gru
# Out:
# Using TensorFlow backend.

# %%
arima_model = arima_gru.arima_model('SPY')
arima = arima_gru.arima_residuals('SPY', arima_model)
arima
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
#             prediction    actual   residual
# date
# 2014-06-18  177.717879  177.7468   0.028921
# 2014-06-19  177.539685  177.0993  -0.440385
# 2014-06-20  177.474349  178.3157   0.841351
# 2014-06-21  177.571554  178.3157   0.744146
# 2014-06-22  177.614291  178.3157   0.701409
# 2014-06-23  177.974316  178.2611   0.286784
# 2014-06-24  178.440658  177.1872  -1.253458
# 2014-06-25  178.825500  177.9881  -0.837400
# ...

# %%
gru_model = arima_gru.gru_model(np.array(arima['residual']))
# Out:
# Train on 87 samples, validate on 5 samples
# Epoch 1/5
# 87/87 [==============================] - 67s 768ms/step - loss: 34.8527 - val_loss: 48.3110
# Epoch 2/5
# 87/87 [==============================] - 64s 741ms/step - loss: 17.3756 - val_loss: 32.0856
# Epoch 3/5
# 87/87 [==============================] - 63s 723ms/step - loss: 14.1805 - val_loss: 25.7406
# Epoch 4/5
# 87/87 [==============================] - 64s 731ms/step - loss: 13.2252 - val_loss: 23.8883
# Epoch 5/5
# 87/87 [==============================] - 65s 749ms/step - loss: 12.8334 - val_loss: 23.4235

# %%
with open('gru_model.pickle', 'wb') as p:
    pickle.dump(gru_model, p)
