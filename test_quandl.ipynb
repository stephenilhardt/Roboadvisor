# %%
import numpy as np
import pandas as pd

import quandl

# %%
quandl.ApiConfig.api_key = 'xrHng9yTJXyUhuGGrD_X'

# %%
meta
# Out:
#                       code                                               name  \
# 0         00XALCATM086NEST  Harmonized Index of Consumer Prices: Overall I...
# 1         00XALCBEM086NEST  Harmonized Index of Consumer Prices: Overall I...
# 2         00XALCBGM086NEST  Harmonized Index of Consumer Prices: Overall I...
# 3         00XALCCHM086NEST  Harmonized Index of Consumer Prices: Overall I...
# 4         00XALCCYM086NEST  Harmonized Index of Consumer Prices: Overall I...
# 5         00XALCCZM086NEST  Harmonized Index of Consumer Prices: Overall I...
# 6         00XALCDEM086NEST  Harmonized Index of Consumer Prices: Overall I...
# 7         00XALCDKM086NEST  Harmonized Index of Consumer Prices: Overall I...
# 8       00XALCE3CCM086NEST  Harmonized Index of Consumer Prices: Overall I...
# 9         00XALCEEM086NEST  Harmonized Index of Consumer Prices: Overall I...
# 10        00XALCESM086NEST  Harmonized Index of Consumer Prices: Overall I...
# ...

# %%
indicators = ['GDP', 'GDPC1','GDPPOT','CPIAUCSL','CPILFESL','GDPDEF','M1','M2','M1V','M2V','DFF','DTB3','DGS5','DGS10','DGS30','T5YIE','T10YIE','T5YIFR','TEDRATE','DPRIME','UNRATE','NROU','NROUST','CIVPART',
              'EMRATIO',]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-6d758e210c8b> in <module>()
# ----> 1 quandl.bulkdownload("FRED")
#
# /Users/Stephen/anaconda3/envs/kojak_env/lib/python2.7/site-packages/quandl/bulkdownload.pyc in bulkdownload(database, **kwargs)
#      22
#      23     filename = kwargs.pop('filename', '.')
# ---> 24     return Database(database).bulk_download_to_file(filename, params=kwargs)
#
# /Users/Stephen/anaconda3/envs/kojak_env/lib/python2.7/site-packages/quandl/model/database.pyc in bulk_download_to_file(self, file_or_folder_path, **options)
#      54             file_path = file_or_folder_path + '/' + os.path.basename(urlparse(r.url).path)
#      55         with open(file_path, 'wb') as fd:
# ---> 56             for chunk in r.iter_content(self.BULK_CHUNK_SIZE):
#      57                 fd.write(chunk)
#      58
#
# ...

# %%
data = quandl.get('FRED/DFF')

# %%
# Out:
# 23626
