# %%
import numpy as np
import pandas as pd

import pickle
import requests

import yahoofinancials

import pandas_datareader.data as pdr
import fix_yahoo_finance as yf

import prices

from fake_useragent import UserAgent

# %%
ua = UserAgent()
user_agent = {'User-agent': ua.random}

# %%
yf.pdr_override()

# %%
with open('tickers.pkl', 'rb') as f:
    tickers = pickle.load(f)

# %%
len(tickers)
# Out:
# 2007

# %%
pdr.get_data_yahoo(tickers[0], actions=True)
# Out:
# [*********************100%***********************]  1 of 1 downloaded
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-a8b95bdb24c0> in <module>()
# ----> 1 pdr.get_data_yahoo(tickers[0], actions=True)
#
# /Users/Stephen/anaconda3/envs/kojak_env/lib/python2.7/site-packages/fix_yahoo_finance/__init__.pyc in download(tickers, start, end, as_panel, group_by, auto_adjust, progress, actions, threads, **kwargs)
#     200         else:
#     201             data = data[['Open', 'High', 'Low',
# --> 202                             'Close', 'Adj Close', 'Volume']]
#     203
#     204     # return single df if only one ticker
#
# /Users/Stephen/anaconda3/envs/kojak_env/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2131         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2132             # either boolean or fancy integer index
# -> 2133             return self._getitem_array(key)
#    2134         elif isinstance(key, DataFrame):
#    2135             return self._getitem_frame(key)
#
# /Users/Stephen/anaconda3/envs/kojak_env/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_array(self, key)
#    2175             return self._take(indexer, axis=0, convert=False)
#    2176         else:
# -> 2177             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2178             return self._take(indexer, axis=1, convert=True)
#    2179
#
# /Users/Stephen/anaconda3/envs/kojak_env/lib/python2.7/site-packages/pandas/core/indexing.pyc in _convert_to_indexer(self, obj, axis, is_setter)
#    1248                 # if it cannot handle
#    1249                 indexer, objarr = labels._convert_listlike_indexer(
# -> 1250                     obj, kind=self.name)
#    1251                 if indexer is not None:
#    1252                     return indexer
#
# /Users/Stephen/anaconda3/envs/kojak_env/lib/python2.7/site-packages/pandas/core/indexes/multi.pyc in _convert_listlike_indexer(self, keyarr, kind)
#    1796                                                               tuple):
#    1797             level = 0
# -> 1798             _, indexer = self.reindex(keyarr, level=level)
#    1799
#    1800             # take all
#
# /Users/Stephen/anaconda3/envs/kojak_env/lib/python2.7/site-packages/pandas/core/indexes/multi.pyc in reindex(self, target, method, level, limit, tolerance)
#    1890             target, indexer, _ = self._join_level(target, level, how='right',
#    1891                                                   return_indexers=True,
# -> 1892                                                   keep_order=False)
#    1893         else:
#    1894             target = _ensure_index(target)
#
# /Users/Stephen/anaconda3/envs/kojak_env/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in _join_level(self, other, level, how, return_indexers, keep_order)
#    3334             else:  # tie out the order with other
#    3335                 if level == 0:  # outer most level, take the fast route
# -> 3336                     ngroups = 1 + new_lev_labels.max()
#    3337                     left_indexer, counts = libalgos.groupsort_indexer(
#    3338                         new_lev_labels, ngroups)
#
# /Users/Stephen/anaconda3/envs/kojak_env/lib/python2.7/site-packages/numpy/core/_methods.pyc in _amax(a, axis, out, keepdims)
#      24 # small reductions
#      25 def _amax(a, axis=None, out=None, keepdims=False):
# ---> 26     return umr_maximum(a, axis, None, out, keepdims)
#      27
#      28 def _amin(a, axis=None, out=None, keepdims=False):
#
# ValueError: zero-size array to reduction operation maximum which has no identity

# %%
df = prices.get_yahoo_prices_all_tickers(tickers)
# Out:
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-1c8377998714> in <module>()
# ----> 1 prices.get_yahoo_prices_all_tickers(tickers)
#
# /Users/Stephen/project-kojak/prices.py in get_yahoo_prices_all_tickers(tickers)
#      23                 except:
#      24                         pass
# ---> 25                 time.sleep(2 * np.random.random())
#      26
#      27         return yahoo_prices
#
# KeyboardInterrupt:

# %%
prices.get_yahoo_prices_one_ticker(tickers[16])
# Out:
# [*********************100%***********************]  1 of 1 downloaded
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2008-11-19  47.790001  50.799999  40.709999  41.000000  35.125454   560900
# 2008-11-20  39.980000  39.980000  26.629999  27.100000  23.217070   854700
# 2008-11-21  29.889999  36.730000  28.000000  36.230000  31.038902  1125200
# 2008-11-24  40.099998  45.880001  36.419998  42.290001  36.230621  1108000
# 2008-11-25  44.290001  46.160000  40.720001  44.000000  37.695610   601800
# 2008-11-26  42.750000  51.990002  42.000000  51.900002  44.463688   676800
# 2008-11-28  49.500000  49.860001  46.439999  49.360001  42.287621   181900
# 2008-12-01  43.160000  44.590000  34.110001  34.500000  29.556784   702700
# 2008-12-02  36.619999  38.090000  34.000000  37.660000  32.264015   959100
# 2008-12-03  34.270000  38.810001  33.660000  38.680000  33.137863  1320800
# 2008-12-04  36.480000  37.900002  29.090000  31.090000  26.635378  1339000
# 2008-12-05  28.959999  32.689999  25.600000  32.500000  27.843353  2187100
# 2008-12-08  36.400002  38.580002  35.340000  36.759998  31.492973  1986700
# 2008-12-09  35.599998  40.080002  35.119999  36.919998  31.630045  1608000
# 2019-03-04  23.200001  23.340000  22.000000  23.030001  23.030001  3989500
# 2019-03-05  23.170000  23.170000  22.330000  22.820000  22.820000  2429900
# 2019-03-06  22.320000  22.370001  21.600000  21.930000  21.930000  2874200
# 2019-03-07  21.950001  22.000000  21.290001  21.530001  21.530001  3092600
# 2019-03-08  20.490000  20.570000  19.740000  20.299999  20.299999  3163240
#
#             Dividends  Stock Splits Ticker
# Date
# 2008-11-19      0.000           1.0    ERX
# 2008-11-20      0.000           1.0    ERX
# 2008-11-21      0.000           1.0    ERX
# 2008-11-24      0.000           1.0    ERX
# 2008-11-25      0.000           1.0    ERX
# 2008-11-26      0.000           1.0    ERX
# 2008-11-28      0.000           1.0    ERX
# 2008-12-01      0.000           1.0    ERX
# 2008-12-02      0.000           1.0    ERX
# 2008-12-03      0.000           1.0    ERX
# 2008-12-04      0.000           1.0    ERX
# 2008-12-05      0.000           1.0    ERX
# 2008-12-08      0.000           1.0    ERX
# 2008-12-09      0.000           1.0    ERX
# 2008-12-10      0.000           1.0    ERX
# 2008-12-11      0.000           1.0    ERX
# 2008-12-12      0.000           1.0    ERX
# 2008-12-15      0.000           1.0    ERX
# 2008-12-16      0.000           1.0    ERX
# 2008-12-17      0.008           1.0    ERX
# 2008-12-18      0.000           1.0    ERX
# 2008-12-19      0.000           1.0    ERX
# 2008-12-22      0.000           1.0    ERX
# 2008-12-23      0.000           1.0    ERX
# 2008-12-24      0.000           1.0    ERX
# 2008-12-26      0.000           1.0    ERX
# 2008-12-29      0.000           1.0    ERX
# 2008-12-30      0.000           1.0    ERX
# 2008-12-31      0.000           1.0    ERX
# 2009-01-02      0.000           1.0    ERX
# ...               ...           ...    ...
# 2019-01-25      0.000           1.0    ERX
# 2019-01-28      0.000           1.0    ERX
# 2019-01-29      0.000           1.0    ERX
# 2019-01-30      0.000           1.0    ERX
# 2019-01-31      0.000           1.0    ERX
# 2019-02-01      0.000           1.0    ERX
# 2019-02-04      0.000           1.0    ERX
# 2019-02-05      0.000           1.0    ERX
# 2019-02-06      0.000           1.0    ERX
# 2019-02-07      0.000           1.0    ERX
# 2019-02-08      0.000           1.0    ERX
# 2019-02-11      0.000           1.0    ERX
# 2019-02-12      0.000           1.0    ERX
# 2019-02-13      0.000           1.0    ERX
# 2019-02-14      0.000           1.0    ERX
# 2019-02-15      0.000           1.0    ERX
# 2019-02-19      0.000           1.0    ERX
# 2019-02-20      0.000           1.0    ERX
# 2019-02-21      0.000           1.0    ERX
# 2019-02-22      0.000           1.0    ERX
# 2019-02-25      0.000           1.0    ERX
# 2019-02-26      0.000           1.0    ERX
# 2019-02-27      0.000           1.0    ERX
# 2019-02-28      0.000           1.0    ERX
# 2019-03-01      0.000           1.0    ERX
# 2019-03-04      0.000           1.0    ERX
# 2019-03-05      0.000           1.0    ERX
# 2019-03-06      0.000           1.0    ERX
# 2019-03-07      0.000           1.0    ERX
# 2019-03-08      0.000           1.0    ERX
#
# [2591 rows x 9 columns]

# %%
spy = yahoofinancials.YahooFinancials('SPY')

# %%
start = datetime.datetime(2016, 1, 1)
end = datetime.datetime(2019, 1, 1)

# %%
pdr.get_data_yahoo('SPY', start, end, actions=True)

# %%
pdr.get_data_yahoo_actions('SPY', start, end)
