# %%
import numpy as np
import pandas as pd
import pickle
import time

import psycopg2

import prices

import pandas_datareader as pdr

# %%
with open('tickers.pkl', 'rb') as f:
    tickers = pickle.load(f)

# %%
len(tickers)
# Out:
# 2007

# %%
for index, ticker in enumerate(tickers):
    try:
        time.sleep(5 * np.random.random())
        
        prices.price_to_csv('/Users/Stephen/csvs/', ticker)
        print(index)
    except:
        print('Skipping', ticker)

# %%
test_df = pd.read_csv('/Users/Stephen/csvs/UWT.csv')

# %%
prices.get_yahoo_prices_one_ticker('WANT')
# Out:
# [*********************100%***********************]  1 of 1 downloaded
#                  Open       High        Low      Close  Adj Close  Volume  \
# Date
# 2018-11-29  24.770000  24.959999  24.770000  24.927000  24.927000     500
# 2018-11-30  24.927000  24.927000  24.927000  24.927000  24.927000       0
# 2018-12-03  26.209999  26.209999  26.209999  26.209999  26.209999     400
# 2018-12-04  25.959999  25.959999  24.379999  24.379999  24.379999     400
# 2018-12-06  22.650000  23.730000  22.650000  23.730000  23.730000    1100
# 2018-12-07  23.450001  23.450001  21.686001  21.686001  21.686001     700
# 2018-12-10  21.180000  21.958000  21.180000  21.958000  21.958000     300
# 2018-12-11  21.948000  21.948000  21.948000  21.948000  21.948000     100
# 2018-12-12  23.090000  23.379999  22.684999  22.684999  22.684999     300
# 2018-12-13  22.850000  22.850000  22.000000  22.326000  22.326000    1600
# 2018-12-14  21.750000  21.750000  21.205000  21.205000  21.205000     700
# ...

# %%
symbols = pdr.get_nasdaq_symbols()

# %%
etfs = symbols[symbols['ETF'] == True]

# %%
etfs
# Out:
#         Nasdaq Traded                                      Security Name  \
# Symbol
# AAAU             True                       Perth Mint Physical Gold ETF
# AADR             True                AdvisorShares Dorsey Wright ADR ETF
# AAXJ             True  iShares MSCI All Country Asia ex Japan Index Fund
# ACES             True                              ALPS Clean Energy ETF
# ACIM             True                             SPDR MSCI ACWI IMI ETF
# ACSG             True  Xtrackers MSCI ACWI ex USA ESG Leaders Equity ETF
# ACSI             True                 American Customer Satisfaction ETF
# ACT              True                             AdvisorShares Vice ETF
# ACWF             True           iShares Edge MSCI Multifactor Global ETF
# ACWI             True                       iShares MSCI ACWI Index Fund
# ACWV             True               iShares Edge MSCI Min Vol Global ETF
# ACWX             True                 iShares MSCI ACWI ex US Index Fund
# ...

# %%
pdr.data.get_data_yahoo('SPY', actions=True)
# Out:
# [*********************100%***********************]  1 of 1 downloaded
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-29   43.968700   43.968700   43.750000   43.937500   26.954851
# 1993-02-01   43.968700   44.250000   43.968700   44.250000   27.146563
# 1993-02-02   44.218700   44.375000   44.125000   44.343700   27.204052
# 1993-02-03   44.406200   44.843700   44.375000   44.812500   27.491642
# 1993-02-04   44.968700   45.093700   44.468700   45.000000   27.606684
# 1993-02-05   44.968700   45.062500   44.718700   44.968700   27.587467
# 1993-02-08   44.968700   45.125000   44.906200   44.968700   27.587467
# 1993-02-09   44.812500   44.812500   44.562500   44.656200   27.395754
# 1993-02-10   44.656200   44.750000   44.531200   44.718700   27.434109
# 1993-02-11   44.781200   45.125000   44.781200   44.937500   27.568338
# 1993-02-12   44.875000   44.875000   44.593700   44.593700   27.357416
# ...

# %%
pdr.get_data_yahoo_actions('SPY').reset_index().rename(columns={'index': 'Date'})
# Out:
#          Date    action    value
# 0  2018-12-21  DIVIDEND  1.43500
# 1  2018-09-21  DIVIDEND  1.32300
# 2  2018-06-15  DIVIDEND  1.24600
# 3  2018-03-16  DIVIDEND  1.09700
# 4  2017-12-15  DIVIDEND  1.35100
# 5  2017-09-15  DIVIDEND  1.23500
# 6  2017-06-16  DIVIDEND  1.18300
# 7  2017-03-17  DIVIDEND  1.03300
# 8  2016-12-16  DIVIDEND  1.32893
# 9  2016-09-16  DIVIDEND  1.08207
# 10 2016-06-17  DIVIDEND  1.07844
# 11 2016-03-18  DIVIDEND  1.04960
# 12 2015-12-18  DIVIDEND  1.21155
# 13 2015-09-18  DIVIDEND  1.03343
# 14 2015-06-19  DIVIDEND  1.03007
# 15 2015-03-20  DIVIDEND  0.93081
# 16 2014-12-19  DIVIDEND  1.13492
# 17 2014-09-19  DIVIDEND  0.93919
# 18 2014-06-20  DIVIDEND  0.93669
# 19 2014-03-21  DIVIDEND  0.82461
# 20 2013-12-20  DIVIDEND  0.98025
# 21 2013-09-20  DIVIDEND  0.83795
# 22 2013-06-21  DIVIDEND  0.83900
# 23 2013-03-15  DIVIDEND  0.69400
# 24 2012-12-21  DIVIDEND  1.02200
# 25 2012-09-21  DIVIDEND  0.77900
# 26 2012-06-15  DIVIDEND  0.68800
# ...

# %%
pdr.get_data_yahoo('SPY')
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2010-01-04  113.389999  111.510002  112.370003  113.330002  118944600.0
# 2010-01-05  113.680000  112.849998  113.260002  113.629997  111579900.0
# 2010-01-06  113.989998  113.430000  113.519997  113.709999  116074400.0
# 2010-01-07  114.330002  113.180000  113.500000  114.190002  131091100.0
# 2010-01-08  114.620003  113.660004  113.889999  114.570000  126402800.0
# 2010-01-11  115.129997  114.239998  115.080002  114.730003  106375700.0
# 2010-01-12  114.209999  113.220001  113.970001  113.660004  163333500.0
# 2010-01-13  114.940002  113.370003  113.949997  114.620003  161822000.0
# 2010-01-14  115.139999  114.419998  114.489998  114.930000  115718800.0
# 2010-01-15  114.839996  113.199997  114.730003  113.639999  212283100.0
# 2010-01-19  115.129997  113.589996  113.620003  115.059998  139172700.0
# 2010-01-20  114.449997  112.980003  114.279999  113.889999  216490200.0
# ...

# %%
pdr.get_iex_symbols('SPY')
# Out:
#             date     iexId  isEnabled  \
# 0     2019-03-11         2       True
# 1     2019-03-11     12042       True
# 2     2019-03-11     14924       True
# 3     2019-03-11      7653       True
# 4     2019-03-11      9169       True
# 5     2019-03-11         5       True
# 6     2019-03-11      8148       True
# 7     2019-03-11      7760       True
# 8     2019-03-11         7       True
# 9     2019-03-11         8       True
# 10    2019-03-11      7790       True
# 11    2019-03-11         9       True
# 12    2019-03-11        10       True
# 13    2019-03-11        11       True
# 14    2019-03-11        12       True
# 15    2019-03-11        13       True
# 16    2019-03-11        15       True
# 17    2019-03-11        16       True
# 18    2019-03-11      6667       True
# 19    2019-03-11        17       True
# 20    2019-03-11        19       True
# 21    2019-03-11        20       True
# 22    2019-03-11        21       True
# ...
