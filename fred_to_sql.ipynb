# %%
import numpy as np
import pandas as pd

import quandl

from sqlalchemy import create_engine

# %%
quandl.ApiConfig.api_key = 'xrHng9yTJXyUhuGGrD_X'

# %%
quandl.bulkdownload("FRED")
# Out:
# u'./FRED.zip'

# %%
df = pd.read_csv('FRED_20190312.csv', header=None)

# %%
df
# Out:
#                          0           1        2
# 0         00XALCATM086NEST  1996-01-01    71.77
# 1         00XALCATM086NEST  1996-02-01    72.01
# 2         00XALCATM086NEST  1996-03-01    72.18
# 3         00XALCATM086NEST  1996-04-01    72.11
# 4         00XALCATM086NEST  1996-05-01    72.03
# 5         00XALCATM086NEST  1996-06-01    72.27
# 6         00XALCATM086NEST  1996-07-01    72.36
# 7         00XALCATM086NEST  1996-08-01    72.12
# 8         00XALCATM086NEST  1996-09-01    72.14
# 9         00XALCATM086NEST  1996-10-01    72.29
# 10        00XALCATM086NEST  1996-11-01    72.48
# 11        00XALCATM086NEST  1996-12-01    72.67
# 12        00XALCATM086NEST  1997-01-01    72.59
# 13        00XALCATM086NEST  1997-02-01    72.99
# 14        00XALCATM086NEST  1997-03-01    73.02
# 15        00XALCATM086NEST  1997-04-01    73.01
# 16        00XALCATM086NEST  1997-05-01    72.99
# 17        00XALCATM086NEST  1997-06-01    73.02
# 18        00XALCATM086NEST  1997-07-01    72.97
# ...

# %%
meta = pd.read_csv('FRED_metadata.csv')

# %%
meta
# Out:
#                       code                                               name  \
# 0         00XALCATM086NEST  Harmonized Index of Consumer Prices: Overall I...
# 1         00XALCBEM086NEST  Harmonized Index of Consumer Prices: Overall I...
# 2         00XALCBGM086NEST  Harmonized Index of Consumer Prices: Overall I...
# 3         00XALCCHM086NEST  Harmonized Index of Consumer Prices: Overall I...
# 4         00XALCCYM086NEST  Harmonized Index of Consumer Prices: Overall I...
# 5         00XALCCZM086NEST  Harmonized Index of Consumer Prices: Overall I...
# 6         00XALCDEM086NEST  Harmonized Index of Consumer Prices: Overall I...
# 7         00XALCDKM086NEST  Harmonized Index of Consumer Prices: Overall I...
# 8       00XALCE3CCM086NEST  Harmonized Index of Consumer Prices: Overall I...
# 9         00XALCEEM086NEST  Harmonized Index of Consumer Prices: Overall I...
# 10        00XALCESM086NEST  Harmonized Index of Consumer Prices: Overall I...
# ...

# %%
df.head()
# Out:
#                   0           1      2
# 0  00XALCATM086NEST  1996-01-01  71.77
# 1  00XALCATM086NEST  1996-02-01  72.01
# 2  00XALCATM086NEST  1996-03-01  72.18
# 3  00XALCATM086NEST  1996-04-01  72.11
# 4  00XALCATM086NEST  1996-05-01  72.03

# %%
df.columns = ['code', 'date', 'value']

# %%
engine = create_engine('postgres://ubuntu:project-kojak@localhost:5432/roboadvisor')

# %%
meta.to_sql('macro_metadata', engine, index=False, if_exists='append')
